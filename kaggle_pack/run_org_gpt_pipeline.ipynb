# %% [markdown]
# # OrgGPT: Constitutional LLM Agents for Measuring Bureaucratic Entropy
# ## Kaggle Master Execution Pipeline
#
# This notebook runs the Red-Blue adversarial graph simulation utilizing the core algorithms.

# %%
# !pip install -q google-genai pm4py networkx scikit-learn numpy pandas

# %%
import os
from kaggle_secrets import UserSecretsClient

try:
    user_secrets = UserSecretsClient()
    os.environ['GEMINI_API_KEY'] = user_secrets.get_secret('GEMINI_API_KEY')
    print('Secrets loaded successfully.')
except Exception as e:
    print('Error loading secrets, please ensure they are attached to the Kaggle session.')

# %%
# Copy in src code (to be injected via Kaggle Dataset or inline)
print('Initializing Red-Blue Team engines and loading Enron Workflow Data from /kaggle/input/...')
